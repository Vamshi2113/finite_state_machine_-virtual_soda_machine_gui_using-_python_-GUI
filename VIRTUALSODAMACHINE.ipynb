# %%
import tkinter as tk
from tkinter import *
from tkinter import messagebox
lst=[]
global c
def select1():
    select1=1
    lst.append("5")
    print(lst)
def select2():
    select2=1
    lst.append("10")
    print(lst)
def selectpepsi():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="10":
        vselectpepsi=1
        lst.append("PEPSI")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get pepsi for rs 5,here is your refund")
        select4()
        reset()
        
def selectcoke():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="10":
        vselectcoke=1
        lst.append("COKE")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get coke for rs 5,here is your refund")
        select4()
        reset()
def selectsprite():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="10":
        vselectsprite=1
        lst.append("MOUNTAIN DEV")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get mountain dev for rs 5,here is your refund")
        select4()
        reset()
def selectthumbsup():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="10":
        vselectthumbsup=1
        lst.append("THUMBS UP")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get thumbs up for rs 5,here is your refund")
        select4()
        reset()
def selectlays():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="5":
        vselectlays=1
        lst.append("LAYS")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get lays for rs 10,here is your refund")
        select4()
        reset()
def selectkurkure():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="5":
        vselectkurkure=1
        lst.append("KURKURE")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get kurkure for rs 10,here is your refund")
        select4()
        reset()
def selectdoritos():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="5":
        selectdoritos=1
        lst.append("DORITOS")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get doritos for rs 10,here is your refund")
        select4()
        reset()
def selectchips():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
    elif lst[0]=="5":
        vselectchips=1
        lst.append("CHIPS")
        print(lst)
    else:
        messagebox.showinfo("thanks for using our tool","you cant get chips for rs 10,here is your refund")
        select4()
        reset()
def select3():
    selectconfirm=1
    lst.append("confirm")
    print(lst)
    #c=Frame(root,bd=5,relief=SUNKEN)
    #c.pack(side="top")
    if lst[0]=="5":
        #messagebox.showinfo("thanks for using our tool",lst[1])
        label=Label(c,text=lst[1],fg="white",bg="green")
        label.pack(side="top")
        reset()
    elif len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
        reset()
    elif lst[0]=="10":
        label=Label(c,text=lst[1],fg="white",bg="green")
        label.pack(side="top")
        reset()
def select4():
    if len(lst)==0:
        messagebox.showinfo("SNACK'N DRINK MACHINE","please insert coin!")
        reset()
    else:
        selectrefund="1"
        lst.append("refund")
        print(lst)
        #c=Frame(root,bd=5,bg="green",relief=SUNKEN)
        #c.pack(side="top")
        label=Label(c,text=lst[0],fg="white",bg="red")
        label.pack(side="top")
        reset()
    #messagebox.showinfo("thanks for using our tool",lst[0])
def reset():
    print(lst)
    lst.clear()
def clear():
        global c
        c.destroy()
        c=Frame(root,bd=5,bg="green",relief=SUNKEN)
        c.pack(side="top")

root=Toplevel()
root.title("SNACK'N DRINK VENDING MACHINE")

bg=tk.PhotoImage(file=r"C:\Users\panas\Desktop\HTML\Safeimagekit-resized-img.png")
img=Label(root,image=bg)
img.place(x=0,y=0,relwidth=1,relheight=1)
root.geometry("500x500")
root.minsize(500,500)
root.maxsize(500,500)
Label(root,text="SNACK'N DRINK VENDING MACHINE",font="Constantia 15",borderwidth=5,relief=SUNKEN,fg="red",bg="yellow").pack(anchor="center")
a=Frame(root,bg="grey",bd=5,borderwidth=5,relief=SUNKEN)
a.pack()
b=Frame(root,bd=0,bg="green")
b.pack()
Label(a,text="PAY",fg="white",bg="grey",font="Constantia 10").pack(anchor="n",padx=120)
Button(b,text="  5 rs",command=select1).grid(row=0,column=0)
Button(b,text="10 rs",command=select2).grid(row=0,column=1)
a=Frame(root,bg="grey",bd=5,borderwidth=5,relief=SUNKEN)
a.pack()
b=Frame(root,bd=0,bg="green")
b.pack()

Label(a,text="SELECT COLD DRINKS",fg="white",bg="grey",font="Constantia 10").grid(row=3,column=1,padx=65)
Button(b,text="        pepsi        ",command=selectpepsi).grid(row=1,column=0)
Button(b,text="     coke      ",command=selectcoke).grid(row=1,column=1)
Button(b,text="mountain dev",command=selectsprite).grid(row=5,column=0)
Button(b,text="thumbs up",command=selectthumbsup).grid(row=5,column=1)
a=Frame(root,bg="grey",bd=5,borderwidth=5,relief=SUNKEN)
a.pack()
b=Frame(root,bd=0,bg="green")
b.pack()

Label(a,text="SELECT SNACKS",fg="white",bg="grey",font="Constantia 10").grid(row=3,column=1,padx=85)
Button(b,text="  lays   ",command=selectlays).grid(row=1,column=0)
Button(b,text=" kurkure ",command=selectkurkure).grid(row=1,column=1)
Button(b,text="doritos",command=selectdoritos).grid(row=5,column=0)
Button(b,text="   chips   ",command=selectchips).grid(row=5,column=1)
a=Frame(root,bg="grey",bd=5,borderwidth=5,relief=SUNKEN)
a.pack()
b=Frame(root,bd=0,bg="green")
b.pack()

Label(a,text="CONFIRM",fg="white",bg="grey",font="Constantia 10").pack(anchor="n",side="top",padx=106)
Button(b,text="CONFIRM",command=select3,bg="green",fg="white").grid(row=1,column=0)
Button(b,text="REFUND",command=select4,bg="red",fg="white").grid(row=1,column=1)
Button(b,text="  RESET  ",command=reset,bg="#FFFF99",fg="black").grid(row=1,column=2)
Button(b,text="\b",command=clear,bg="blue",fg="white").grid(row=1,column=3)
b=Frame(root,bd=0,bg="green")
b.pack()
c=Frame(root,bd=5,bg="green",relief=SUNKEN)
c.pack(side="top")

root.mainloop()
